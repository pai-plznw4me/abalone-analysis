# %%
import pandas as pd 
from helper import compare_jindo_wando, compare_small_big
from helper import extract_albarone_polygon_images

# %%
wando_df = pd.read_csv('../datasets/wando_add_meta.csv', index_col=[0], converters={'segmentation': eval})

# %%
jindo_df = pd.read_csv('../datasets/jindo_add_meta.csv', index_col=[0], converters={'segmentation': eval})

# %% [markdown]
# # 1. ADULT BIG vs SMALL

# %% [markdown]
# ## 1.1 WANDO

# %%
wabf_images, wabf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='BIG', side='f')
wasf_images, wasf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='SMALL', side='f')
compare_small_big(wabf_images, wabf_meta_info, wasf_images, wasf_meta_info)
# Out:
# LARGE L/S 비율 : 1.5338623869735777
# SMALL L/S 비율 : 1.5206214831687381
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  34.000000  34.000000  34.000000  50.000000  50.000000  50.000000
# mean    9.717993   6.339965   1.533862   8.035294   5.288235   1.520621
# std     0.237304   0.190223   0.051192   0.306636   0.209832   0.057905
# min     9.235294   6.058824   1.415584   7.058824   4.794118   1.387283
# 25%     9.558824   6.183824   1.501168   7.882353   5.154412   1.484690
# 50%     9.676471   6.294118   1.526929   8.044118   5.294118   1.523396
# 75%     9.911765   6.455882   1.579849   8.235294   5.411765   1.552258
# max    10.205882   6.882353   1.628571   8.676471   5.705882   1.680723
# big : R:81.95024791627726 G:81.9535625780077 B69.24770966360967
# small : R:76.0892879461034 G:78.47337131612194 B71.50054410862111

# %% [markdown]
# ## 1.2 JINDO

# %%
jabf_images, jabf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='BIG', side='f')
jasf_images, jasf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='SMALL', side='f')
compare_small_big(jabf_images, jabf_meta_info, jasf_images, jasf_meta_info)
# Out:
# LARGE L/S 비율 : 1.4675633474621759
# SMALL L/S 비율 : 1.5056604359284032
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    8.632353   5.886471   1.467563   7.216471   4.799412   1.505660
# std     0.404509   0.279910   0.056203   0.378746   0.291446   0.064874
# min     7.823529   5.264706   1.354839   6.147059   4.176471   1.384106
# 25%     8.301471   5.683824   1.420547   6.992647   4.602941   1.457392
# 50%     8.647059   5.852941   1.481499   7.235294   4.823529   1.506333
# 75%     8.970588   6.080882   1.504345   7.522059   5.022059   1.542407
# max     9.323529   6.529412   1.601036   8.000000   5.411765   1.686667
# big : R:63.03525493193359 G:62.66698642650967 B51.752763192580424
# small : R:63.73241380580843 G:62.9191729778943 B52.35522798471537

# %% [markdown]
# # 2. BABY BIG

# %% [markdown]
# ## 2.1 WANDO

# %%
wbbf_images, wbbf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='BIG', side='f')
wbsf_images, wbsf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='SMALL', side='f')
compare_small_big(wbbf_images, wbbf_meta_info, wbsf_images, wbsf_meta_info)
# Out:
# LARGE L/S 비율 : 1.4692853763076184
# SMALL L/S 비율 : 1.4918439578015075
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    4.902353   3.339412   1.469285   3.352353   2.248235   1.491844
# std     0.262626   0.191369   0.053397   0.152827   0.083435   0.061889
# min     4.441176   3.058824   1.362903   3.000000   2.088235   1.324675
# 25%     4.735294   3.176471   1.423997   3.272059   2.205882   1.474519
# 50%     4.867647   3.308824   1.474569   3.382353   2.235294   1.500000
# 75%     5.088235   3.492647   1.503151   3.441176   2.294118   1.534742
# max     5.588235   3.705882   1.626168   3.617647   2.411765   1.602740
# big : R:33.40291640482817 G:41.197697929503555 B32.652662387477456
# small : R:38.392329530745734 G:49.54635158690437 B40.681631085722174

# %%
jbbf_images, jbbf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='BIG', side='f')
jbsf_images, jbsf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='SMALL', side='f')
compare_small_big(jbbf_images, jbbf_meta_info, jbsf_images, jbsf_meta_info)
# Out:
# LARGE L/S 비율 : 1.4710831942769167
# SMALL L/S 비율 : 1.4842325403881658
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  73.000000  73.000000  73.000000
# mean    4.903529   3.335882   1.471083   3.285657   2.215149   1.484233
# std     0.264275   0.195646   0.046989   0.187463   0.112945   0.066968
# min     4.470588   2.970588   1.341270   2.911765   2.000000   1.341772
# 25%     4.705882   3.183824   1.437500   3.147059   2.147059   1.438356
# 50%     4.852941   3.294118   1.472222   3.264706   2.205882   1.486486
# 75%     5.029412   3.492647   1.498950   3.411765   2.264706   1.520548
# max     5.647059   3.823529   1.573770   3.911765   2.705882   1.657143
# big : R:34.42920857596612 G:42.27597935415564 B33.75883149407501
# small : R:56.85714529143953 G:72.93989035485185 B71.61079845152176

# %%
wabf_images, wabf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='BIG', side='f')
jabf_images, jabf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='BIG', side='f')
wabb_images, wabb_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='BIG', side='b')
jabb_images, jabb_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='BIG', side='b')

wasf_images, wasf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='SMALL', side='f')
jasf_images, jasf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='SMALL', side='f')
wasf_images, wasf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='SMALL', side='b')
jasf_images, jasf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='SMALL', side='b')

wbbf_images, wbbf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='BIG', side='f')
jbbf_images, jbbf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='BIG', side='f')
wbbb_images, wbbb_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='BIG', side='b')
jbbb_images, jbbb_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='BIG', side='b')

wbsf_images, wbsf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='SMALL', side='f')
jbsf_images, jbsf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='SMALL', side='f')
wbsb_images, wbsb_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='SMALL', side='b')
jbsb_images, jbsb_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='SMALL', side='b')
