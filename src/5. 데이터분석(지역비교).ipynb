# %%
import pandas as pd 
from helper import compare_jindo_wando
from helper import extract_albarone_polygon_images
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from helper import compare_jindo_wando
#       3 from helper import extract_albarone_polygon_images
#
# ModuleNotFoundError: No module named 'helper'

# %%
wando_df = pd.read_csv('../datasets/wando_add_meta.csv', index_col=[0], converters={'segmentation': eval})

# %%
jindo_df = pd.read_csv('../datasets/jindo_add_meta.csv', index_col=[0], converters={'segmentation': eval})

# %% [markdown]
# # 1. ADULT BIG Front

# %%
wabf_images, wabf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='BIG', side='f')
jabf_images, jabf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='BIG', side='f')

# %%
import numpy as np
import matplotlib.pyplot as plt
target_index = np.argwhere(wabf_meta_info[:, 0] == 31)[0][0]
print(target_index)
plt.imshow(wabf_images[target_index])
plt.show()
# Out:
# 15

# %%
compare_jindo_wando(wabf_images, wabf_meta_info, jabf_images[:35], jabf_meta_info[:30])
# Out:
# 완도산 L/S 비율 : 1.5338623869735777
# 진도산 L/S 비율 : 1.4676673271597567
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  34.000000  34.000000  34.000000  30.000000  30.000000  30.000000
# mean    9.717993   6.339965   1.533862   8.643137   5.895098   1.467667
# std     0.237304   0.190223   0.051192   0.428711   0.316462   0.061165
# min     9.235294   6.058824   1.415584   7.823529   5.264706   1.354839
# 25%     9.558824   6.183824   1.501168   8.301471   5.683824   1.416904
# 50%     9.676471   6.294118   1.526929   8.647059   5.882353   1.478430
# 75%     9.911765   6.455882   1.579849   9.036765   6.080882   1.510911
# max    10.205882   6.882353   1.628571   9.235294   6.529412   1.601036
# Wando : R:81.95024791627726 G:81.9535625780077 B69.24770966360967
# Jindo : R:61.58163147242248 G:61.036449059875274 B50.13036228073398

# %% [markdown]
# # 5. ADULT BIG Back

# %%
wabb_images, wabb_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='BIG', side='b')
jabb_images, jabb_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='BIG', side='b')

# %%
compare_jindo_wando(wabb_images, wabb_meta_info, jabb_images, jabb_meta_info)
# Out:
# 완도산 L/S 비율 : 1.5237997227989821
# 진도산 L/S 비율 : 1.464634739962171
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  34.000000  34.000000  34.000000  50.000000  50.000000  50.000000
# mean    9.877163   6.486159   1.523800   8.750000   5.977647   1.464635
# std     0.272703   0.214578   0.048720   0.383310   0.274274   0.046157
# min     9.264706   6.147059   1.421488   7.970588   5.323529   1.369668
# 25%     9.742647   6.352941   1.483377   8.455882   5.801471   1.432069
# 50%     9.838235   6.426471   1.525464   8.779412   6.000000   1.465872
# 75%    10.051471   6.617647   1.562582   9.000000   6.117647   1.497354
# max    10.470588   7.117647   1.628571   9.588235   6.588235   1.548718
# Wando : R:116.7826084574334 G:118.47135757883153 B112.12274948771054
# Jindo : R:106.62970660264723 G:113.00528578646389 B115.93462487811314

# %% [markdown]
# # 6. ADULT SMALL front

# %%
wasf_images, wasf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='SMALL', side='f')
jasf_images, jasf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='SMALL', side='f')

# %%
compare_jindo_wando(wasf_images, wasf_meta_info, jasf_images, jasf_meta_info)
# Out:
# 완도산 L/S 비율 : 1.5206214831687381
# 진도산 L/S 비율 : 1.5056604359284032
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    8.035294   5.288235   1.520621   7.216471   4.799412   1.505660
# std     0.306636   0.209832   0.057905   0.378746   0.291446   0.064874
# min     7.058824   4.794118   1.387283   6.147059   4.176471   1.384106
# 25%     7.882353   5.154412   1.484690   6.992647   4.602941   1.457392
# 50%     8.044118   5.294118   1.523396   7.235294   4.823529   1.506333
# 75%     8.235294   5.411765   1.552258   7.522059   5.022059   1.542407
# max     8.676471   5.705882   1.680723   8.000000   5.411765   1.686667
# Wando : R:76.0892879461034 G:78.47337131612194 B71.50054410862111
# Jindo : R:63.73241380580843 G:62.9191729778943 B52.35522798471537

# %% [markdown]
# # 2. ADULT SMALL Back

# %%
wabf_images, wabf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='SMALL', side='b')
jabf_images, jabf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='SMALL', side='b')

# %%
compare_jindo_wando(wabf_images, wabf_meta_info, jabf_images, jabf_meta_info)
# Out:
# 완도산 L/S 비율 : 1.5276405430184115
# 진도산 L/S 비율 : 1.5065590274669467
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    8.211765   5.380000   1.527641   7.378235   4.904706   1.506559
# std     0.312680   0.213901   0.061162   0.376514   0.296840   0.067721
# min     7.294118   4.794118   1.405263   6.382353   4.088235   1.408284
# 25%     7.970588   5.213235   1.485428   7.154412   4.750000   1.448339
# 50%     8.220588   5.441176   1.522864   7.426471   4.941176   1.505817
# 75%     8.411765   5.529412   1.557293   7.647059   5.058824   1.547372
# max     8.794118   5.705882   1.705521   8.088235   5.705882   1.691781
# Wando : R:107.37120779872738 G:107.55389734499252 B105.85902133497673
# Jindo : R:104.32054884328628 G:111.34328045919827 B112.87635542763884

# %% [markdown]
# # 1. BABY BIG Front

# %%
wbbf_images, wbbf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='BIG', side='f')
jbbf_images, jbbf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='BIG', side='f')

# %%
compare_jindo_wando(wbbf_images, wbbf_meta_info, jbbf_images, jbbf_meta_info)
# Out:
# 완도산 L/S 비율 : 1.4692853763076184
# 진도산 L/S 비율 : 1.4710831942769167
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    4.902353   3.339412   1.469285   4.903529   3.335882   1.471083
# std     0.262626   0.191369   0.053397   0.264275   0.195646   0.046989
# min     4.441176   3.058824   1.362903   4.470588   2.970588   1.341270
# 25%     4.735294   3.176471   1.423997   4.705882   3.183824   1.437500
# 50%     4.867647   3.308824   1.474569   4.852941   3.294118   1.472222
# 75%     5.088235   3.492647   1.503151   5.029412   3.492647   1.498950
# max     5.588235   3.705882   1.626168   5.647059   3.823529   1.573770
# Wando : R:33.40291640482817 G:41.197697929503555 B32.652662387477456
# Jindo : R:34.42920857596612 G:42.27597935415564 B33.75883149407501

# %% [markdown]
# # 1. BABY BIG back

# %%
wbbb_images, wbbb_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='BIG', side='b')
jbbb_images, jbbb_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='BIG', side='b')

# %%
compare_jindo_wando(wbbb_images, wbbb_meta_info, jbbb_images, jbbf_meta_info)
# Out:
# 완도산 L/S 비율 : 1.4860056969084028
# 진도산 L/S 비율 : 1.4710831942769167
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    4.967059   3.347059   1.486006   4.903529   3.335882   1.471083
# std     0.270063   0.212756   0.060866   0.264275   0.195646   0.046989
# min     4.558824   2.970588   1.341085   4.470588   2.970588   1.341270
# 25%     4.772059   3.213235   1.442514   4.705882   3.183824   1.437500
# 50%     4.911765   3.323529   1.490647   4.852941   3.294118   1.472222
# 75%     5.176471   3.500000   1.517277   5.029412   3.492647   1.498950
# max     5.588235   3.882353   1.629630   5.647059   3.823529   1.573770
# Wando : R:108.62050848963464 G:115.1517153464284 B116.41582888362477
# Jindo : R:108.8254449800112 G:115.33969771577753 B116.60147922105587

# %% [markdown]
# # BABY SMALL Front

# %%
wbsf_images, wbsf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='SMALL', side='f')
jbsf_images, jbsf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='SMALL', side='f')

# %%
compare_jindo_wando(wbsf_images, wbsf_meta_info, jbsf_images, jbsf_meta_info)
# Out:
# 완도산 L/S 비율 : 1.4918439578015075
# 진도산 L/S 비율 : 1.4842325403881658
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  73.000000  73.000000  73.000000
# mean    3.352353   2.248235   1.491844   3.285657   2.215149   1.484233
# std     0.152827   0.083435   0.061889   0.187463   0.112945   0.066968
# min     3.000000   2.088235   1.324675   2.911765   2.000000   1.341772
# 25%     3.272059   2.205882   1.474519   3.147059   2.147059   1.438356
# 50%     3.382353   2.235294   1.500000   3.264706   2.205882   1.486486
# 75%     3.441176   2.294118   1.534742   3.411765   2.264706   1.520548
# max     3.617647   2.411765   1.602740   3.911765   2.705882   1.657143
# Wando : R:38.392329530745734 G:49.54635158690437 B40.681631085722174
# Jindo : R:56.85714529143953 G:72.93989035485185 B71.61079845152176

# %% [markdown]
# # WANDO BABY SMALL Back

# %%
wbsb_images, wbsb_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='SMALL', side='b')
jbsb_images, jbsb_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='SMALL', side='b')

# %%
compare_jindo_wando(wbsb_images, wbsb_meta_info, jbsb_images, jbsb_meta_info)
# Out:
# 완도산 L/S 비율 : 1.5069373295130832
# 진도산 L/S 비율 : 1.4549216178886315
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  73.000000  73.000000  73.000000
# mean    3.415294   2.268824   1.506937   3.305399   2.274778   1.454922
# std     0.174826   0.102060   0.079415   0.190839   0.130637   0.074043
# min     2.941176   2.058824   1.287500   2.941176   2.000000   1.271605
# 25%     3.301471   2.205882   1.459604   3.205882   2.205882   1.405063
# 50%     3.441176   2.279412   1.513701   3.294118   2.264706   1.450000
# 75%     3.558824   2.323529   1.562535   3.411765   2.323529   1.493827
# max     3.705882   2.500000   1.671429   3.941176   2.705882   1.617647
# Wando : R:97.36419515536986 G:107.82487271004956 B109.53950217365563
# Jindo : R:110.55355543854326 G:113.11440827971096 B117.13647898092204

# %% [markdown]
# # Compare WANDO BIG SMALL FRONT

# %%
from helper import compare_small_big

compare_small_big(wabf_images, wabf_meta_info, wasf_images, wasf_meta_info)
# Out:
# BIG L/S 비율 : 1.5276405430184115
# SMALL L/S 비율 : 1.5206214831687381
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    8.211765   5.380000   1.527641   8.035294   5.288235   1.520621
# std     0.312680   0.213901   0.061162   0.306636   0.209832   0.057905
# min     7.294118   4.794118   1.405263   7.058824   4.794118   1.387283
# 25%     7.970588   5.213235   1.485428   7.882353   5.154412   1.484690
# 50%     8.220588   5.441176   1.522864   8.044118   5.294118   1.523396
# 75%     8.411765   5.529412   1.557293   8.235294   5.411765   1.552258
# max     8.794118   5.705882   1.705521   8.676471   5.705882   1.680723
# big : R:107.37120779872738 G:107.55389734499252 B105.85902133497673
# small : R:76.0892879461034 G:78.47337131612194 B71.50054410862111
