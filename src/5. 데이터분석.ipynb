# %%
import pandas as pd 
from helper import compare_jindo_wando
from helper import extract_albarone_polygon_images

# %%
wando_df = pd.read_csv('../datasets/wando_add_meta.csv', index_col=[0], converters={'segmentation': eval})

# %%
jindo_df = pd.read_csv('../datasets/jindo_add_meta.csv', index_col=[0], converters={'segmentation': eval})

# %% [markdown]
# # 1. ADULT BIG Front

# %%
wabf_images, wabf_meta_index = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='BIG', side='f')
jabf_images, jabf_meta_index = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='BIG', side='f')

# %%
compare_jindo_wando(wabf_images, wabf_meta_index, jabf_images, jabf_meta_index)
# Out:
# 완도산 L/S 비율 : 1.4889534878252797
# 진도산 L/S 비율 : 1.4485014403459582
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  34.000000  34.000000  34.000000  50.000000  50.000000  50.000000
# mean    9.690311   6.536332   1.488953   8.682353   6.001176   1.448501
# std     0.285363   0.437870   0.105033   0.392627   0.310922   0.061633
# min     8.735294   6.058824   1.049470   7.823529   5.323529   1.295652
# 25%     9.507353   6.323529   1.478878   8.448529   5.823529   1.410084
# 50%     9.676471   6.367647   1.500000   8.764706   5.985294   1.472030
# 75%     9.875000   6.580882   1.545347   9.000000   6.147059   1.496921
# max    10.264706   8.323529   1.610329   9.441176   6.764706   1.572917
# Wando : R:81.95024791627726 G:81.9535625780077 B69.24770966360967
# Jindo : R:63.03525493193359 G:62.66698642650967 B51.752763192580424

# %% [markdown]
# # 5. ADULT BIG Back

# %%
wabb_images, wabb_meta_index = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='BIG', side='b')
jabb_images, jabb_meta_index = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='BIG', side='b')

# %%
compare_jindo_wando(wabb_images, wabb_meta_index, jabb_images, jabb_meta_index)
# Out:
# 완도산 L/S 비율 : 1.5083717158356098
# 진도산 L/S 비율 : 1.4169935693136315
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  34.000000  34.000000  34.000000  50.000000  50.000000  50.000000
# mean    9.897059   6.566609   1.508372   8.711176   6.165882   1.416994
# std     0.273449   0.222385   0.053276   0.382546   0.398197   0.087382
# min     9.323529   6.147059   1.396552   7.735294   5.411765   1.162055
# 25%     9.764706   6.419118   1.467693   8.529412   5.889706   1.364436
# 50%     9.852941   6.573529   1.517082   8.720588   6.117647   1.433252
# 75%    10.022059   6.705882   1.552088   8.963235   6.323529   1.481867
# max    10.529412   7.176471   1.631579   9.441176   7.441176   1.525253
# Wando : R:116.7826084574334 G:118.47135757883153 B112.12274948771054
# Jindo : R:106.62970660264723 G:113.00528578646389 B115.93462487811314

# %% [markdown]
# # 6. ADULT SMALL front

# %%
wasf_images, wasf_meta_index = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='SMALL', side='f')
jasf_images, jasf_meta_index = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='SMALL', side='f')

# %%
compare_jindo_wando(wasf_images, wasf_meta_index, jasf_images, jasf_meta_index)
# Out:
# 완도산 L/S 비율 : 1.4968553453388256
# 진도산 L/S 비율 : 1.473305226300111
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    8.060000   5.389412   1.496855   7.237647   4.921765   1.473305
# std     0.309784   0.211638   0.062807   0.365997   0.302148   0.074021
# min     7.088235   4.882353   1.366492   6.294118   4.235294   1.231183
# 25%     7.911765   5.242647   1.459064   6.970588   4.720588   1.427368
# 50%     8.073529   5.411765   1.494723   7.279412   4.941176   1.477226
# 75%     8.264706   5.529412   1.533988   7.492647   5.117647   1.514489
# max     8.705882   5.794118   1.672619   8.000000   5.470588   1.605442
# Wando : R:76.0892879461034 G:78.47337131612194 B71.50054410862111
# Jindo : R:63.73241380580843 G:62.9191729778943 B52.35522798471537

# %% [markdown]
# # 2. ADULT SMALL Back

# %%
wabf_images, wabf_meta_index = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='SMALL', side='b')
jabf_images, jabf_meta_index = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='SMALL', side='b')

# %%
compare_jindo_wando(wabf_images, wabf_meta_index, jabf_images, jabf_meta_index)
# Out:
# 완도산 L/S 비율 : 1.4719654298482525
# 진도산 L/S 비율 : 1.4730753695694703
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    8.161176   5.571176   1.471965   7.389412   5.026471   1.473075
# std     0.403109   0.371752   0.125322   0.375319   0.310995   0.078752
# min     7.000000   5.029412   1.094421   6.411765   4.147059   1.273743
# 25%     7.948529   5.360294   1.460205   7.154412   4.889706   1.421169
# 50%     8.205882   5.558824   1.498691   7.397059   5.029412   1.463949
# 75%     8.441176   5.669118   1.541637   7.639706   5.205882   1.522825
# max     8.823529   6.852941   1.678363   8.117647   5.794118   1.680272
# Wando : R:107.37120779872738 G:107.55389734499252 B105.85902133497673
# Jindo : R:104.32054884328628 G:111.34328045919827 B112.87635542763884

# %% [markdown]
# # 1. BABY BIG Front

# %%
wbbf_images, wbbf_meta_index = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='BIG', side='f')
jbbf_images, jbbf_meta_index = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='BIG', side='f')

# %%
compare_jindo_wando(wbbf_images, wbbf_meta_index, jbbf_images, jbbf_meta_index)
# Out:
# 완도산 L/S 비율 : 1.4041724063621708
# 진도산 L/S 비율 : 1.4211236685350586
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    4.866471   3.481176   1.404172   4.897059   3.464706   1.421124
# std     0.293469   0.269875   0.111771   0.272705   0.307039   0.109837
# min     4.205882   3.058824   1.028777   4.411765   2.970588   1.027397
# 25%     4.683824   3.294118   1.337473   4.735294   3.235294   1.393821
# 50%     4.852941   3.411765   1.442050   4.867647   3.397059   1.443461
# 75%     5.000000   3.654412   1.476274   5.000000   3.610294   1.486174
# max     5.617647   4.176471   1.614679   5.676471   4.294118   1.556452
# Wando : R:33.40291640482817 G:41.197697929503555 B32.652662387477456
# Jindo : R:34.42920857596612 G:42.27597935415564 B33.75883149407501

# %% [markdown]
# # 1. BABY BIG back

# %%
wbbb_images, wbbb_meta_index = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='BIG', side='b')
jbbb_images, jbbb_meta_index = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='BIG', side='b')

# %%
compare_jindo_wando(wbbb_images, wbbb_meta_index, jbbb_images, jbbf_meta_index)
# Out:
# 완도산 L/S 비율 : 1.4133955371194173
# 진도산 L/S 비율 : 1.4043381096897334
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean    4.935882   3.507059   1.413396   4.935882   3.533529   1.404338
# std     0.292594   0.271687   0.108140   0.300688   0.295496   0.117191
# min     4.382353   3.029412   1.071429   4.205882   3.000000   1.007042
# 25%     4.676471   3.301471   1.386887   4.713235   3.352941   1.357038
# 50%     4.852941   3.455882   1.437139   4.897059   3.514706   1.428571
# 75%     5.147059   3.669118   1.486012   5.132353   3.698529   1.475325
# max     5.647059   4.529412   1.553571   5.735294   4.294118   1.568627
# Wando : R:108.62050848963464 G:115.1517153464284 B116.41582888362477
# Jindo : R:108.8254449800112 G:115.33969771577753 B116.60147922105587

# %% [markdown]
# # BABY SMALL Front

# %%
wbsf_images, wbsf_meta_index = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='SMALL', side='f')
jbsf_images, jbsf_meta_index = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='SMALL', side='f')

# %%
compare_jindo_wando(wbsf_images, wbsf_meta_index, jbsf_images, jbsf_meta_index)
# Out:
# 완도산 L/S 비율 : 1.3776810026890258
# 진도산 L/S 비율 : 1.4205033869150845
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  73.000000  73.000000  73.000000
# mean    3.313529   2.423529   1.377681   3.289283   2.324335   1.420503
# std     0.179507   0.203250   0.144864   0.201519   0.160495   0.112300
# min     2.911765   2.088235   1.042105   2.852941   2.058824   1.000000
# 25%     3.183824   2.294118   1.304582   3.147059   2.205882   1.371795
# 50%     3.382353   2.352941   1.408537   3.294118   2.294118   1.440000
# 75%     3.433824   2.470588   1.487179   3.411765   2.382353   1.493151
# max     3.617647   2.970588   1.577465   3.941176   2.852941   1.633803
# Wando : R:38.392329530745734 G:49.54635158690437 B40.681631085722174
# Jindo : R:56.85714529143953 G:72.93989035485185 B71.61079845152176

# %% [markdown]
# # WANDO BABY SMALL Back

# %%
wbsb_images, wbsb_meta_index = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='SMALL', side='b')
jbsb_images, jbsb_meta_index = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='SMALL', side='b')

# %%
compare_jindo_wando(wbsb_images, wbsb_meta_index, jbsb_images, jbsb_meta_index)
# Out:
# 완도산 L/S 비율 : 1.413130888921981
# 진도산 L/S 비율 : 1.3660366160568467
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  50.000000  50.000000  50.000000  73.000000  73.000000  73.000000
# mean    3.388235   2.418824   1.413131   3.289283   2.421031   1.366037
# std     0.198593   0.222456   0.155803   0.208953   0.192422   0.124450
# min     2.911765   2.117647   1.019048   2.676471   2.058824   1.009804
# 25%     3.301471   2.264706   1.365912   3.176471   2.264706   1.320513
# 50%     3.397059   2.382353   1.460606   3.294118   2.382353   1.382716
# 75%     3.529412   2.470588   1.500000   3.382353   2.500000   1.446809
# max     3.735294   3.088235   1.638889   4.000000   3.000000   1.597403
# Wando : R:97.36419515536986 G:107.82487271004956 B109.53950217365563
# Jindo : R:110.55355543854326 G:113.11440827971096 B117.13647898092204
