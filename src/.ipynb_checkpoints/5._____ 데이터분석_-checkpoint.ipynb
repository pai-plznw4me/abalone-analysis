# %%
import pandas as pd 
from helper import compare_jindo_wando
from helper import extract_albarone_polygon_images
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from helper import compare_jindo_wando
#       3 from helper import extract_albarone_polygon_images
#
# ModuleNotFoundError: No module named 'helper'

# %%
wando_df = pd.read_csv('../datasets/wando_add_meta.csv', index_col=[0], converters={'segmentation': eval})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 wando_df = pd.read_csv('../datasets/wando_add_meta.csv', index_col=[0], converters={'segmentation': eval})
#
# File ~/anaconda3/envs/abalone-analysis_py3_9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/abalone-analysis_py3_9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/anaconda3/envs/abalone-analysis_py3_9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/abalone-analysis_py3_9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/anaconda3/envs/abalone-analysis_py3_9/lib/python3.9/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../datasets/wando_add_meta.csv'

# %%
jindo_df = pd.read_csv('../datasets/jindo_add_meta.csv', index_col=[0], converters={'segmentation': eval})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 jindo_df = pd.read_csv('../datasets/jindo_add_meta.csv', index_col=[0], converters={'segmentation': eval})
#
# File ~/anaconda3/envs/abalone-analysis_py3_9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/abalone-analysis_py3_9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/anaconda3/envs/abalone-analysis_py3_9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/abalone-analysis_py3_9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/anaconda3/envs/abalone-analysis_py3_9/lib/python3.9/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../datasets/jindo_add_meta.csv'

# %% [markdown]
# # 1. ADULT BIG Front

# %%
wabf_images, wabf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='BIG', side='f')
wasf_images, wasf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='SMALL', side='f')

# %%
compare_jindo_wando(wabf_images, wabf_meta_info, wasf_images, wasf_meta_info)
# Out:
# 완도산 L/S 비율 : 1.533862386973578
# 진도산 L/S 비율 : 1.5206214831687381
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  34.000000  34.000000  34.000000  50.000000  50.000000  50.000000
# mean   11.013725   7.185294   1.533862   9.106667   5.993333   1.520621
# std     0.268945   0.215586   0.051192   0.347521   0.237809   0.057905
# min    10.466667   6.866667   1.415584   8.000000   5.433333   1.387283
# 25%    10.833333   7.008333   1.501168   8.933333   5.841667   1.484690
# 50%    10.966667   7.133333   1.526929   9.116667   6.000000   1.523396
# 75%    11.233333   7.316667   1.579849   9.333333   6.133333   1.552258
# max    11.566667   7.800000   1.628571   9.833333   6.466667   1.680723
# Wando : R:81.95024791627726 G:81.9535625780077 B69.24770966360967
# Jindo : R:76.0892879461034 G:78.47337131612194 B71.50054410862111

# %%
wabf_images, wabf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='BIG', side='f')
jabf_images, jabf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='BIG', side='f')
wabb_images, wabb_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='BIG', side='b')
jabb_images, jabb_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='BIG', side='b')

wasf_images, wasf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='SMALL', side='f')
jasf_images, jasf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='SMALL', side='f')
wasf_images, wasf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='ADULT', size_='SMALL', side='b')
jasf_images, jasf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='ADULT', size_='SMALL', side='b')

wbbf_images, wbbf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='BIG', side='f')
jbbf_images, jbbf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='BIG', side='f')
wbbb_images, wbbb_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='BIG', side='b')
jbbb_images, jbbb_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='BIG', side='b')

wbsf_images, wbsf_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='SMALL', side='f')
jbsf_images, jbsf_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='SMALL', side='f')
wbsb_images, wbsb_meta_info = extract_albarone_polygon_images(wando_df, region='WANDO', entity='BABY', size_='SMALL', side='b')
jbsb_images, jbsb_meta_info = extract_albarone_polygon_images(jindo_df, region='JINDO', entity='BABY', size_='SMALL', side='b')

# %%
compare_jindo_wando(wabf_images, wabf_meta_info, wasf_images, wasf_meta_info)
# Out:
# 완도산 L/S 비율 : 1.533862386973578
# 진도산 L/S 비율 : 1.527640543018412
#         long(cm)  short(cm)     ratios   long(cm)  short(cm)     ratios
# count  34.000000  34.000000  34.000000  50.000000  50.000000  50.000000
# mean   11.013725   7.185294   1.533862   9.306667   6.097333   1.527641
# std     0.268945   0.215586   0.051192   0.354370   0.242422   0.061162
# min    10.466667   6.866667   1.415584   8.266667   5.433333   1.405263
# 25%    10.833333   7.008333   1.501168   9.033333   5.908333   1.485428
# 50%    10.966667   7.133333   1.526929   9.316667   6.166667   1.522864
# 75%    11.233333   7.316667   1.579849   9.533333   6.266667   1.557293
# max    11.566667   7.800000   1.628571   9.966667   6.466667   1.705521
# Wando : R:81.95024791627726 G:81.9535625780077 B69.24770966360967
# Jindo : R:107.37120779872738 G:107.55389734499252 B105.85902133497673
